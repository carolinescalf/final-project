# %%
import pandas as pd

towers = pd.read_csv("cell_towers.csv")
towers.head()
# Out:
#               X              Y  FID               PIN   MAPBLOCKLOT  MUNICODE  \
# 0  1.310994e+06  416621.397980    1  0152A00174000000     152-A-174       939
# 1  1.387932e+06  380383.827738    3  0379M00020000000      379-M-20       408
# 2  1.294820e+06  469468.257837    5  1063B00145000100  1063-B-145-1       883
# 3  1.376124e+06  427677.081577    6  0228E00168000000     228-E-168       931
# 4  1.367142e+06  417381.036552    7  0125F00047000000      125-F-47       112
#
#    TAXYR                    NAME  CARD  LLINE  ... UNITS YRBLT  EFFYR  \
# 0   2016                Robinson     1      2  ...     1  1990    NaN
# 1   2016  8th Ward  - McKEESPORT     1      3  ...     1  2000    NaN
# 2   2016              Bell Acres     1      6  ...     1  1997    NaN
# 3   2016                 O''Hara     1      7  ...     1  2005    NaN
# 4   2016  12th Ward - PITTSBURGH     1      6  ...     1  1998    NaN
#
# ...

# %%
towers['MUNICODE'].value_counts()
# Out:
# 934    14
# 925    10
# 880    10
# 940     8
# 870     6
#        ..
# 118     1
# 116     1
# 114     1
# 110     1
# 106     1
# Name: MUNICODE, Length: 74, dtype: int64
