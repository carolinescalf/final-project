# %%
import pandas as pd
import geopandas
import numpy as np
top10_income = pd.read_csv('income.csv')
top10_income.head(20)
# Out:
#       FIRST_NAME   LAST_NAME               DEPARTMENT  \
# 0      CATHERINE       ABALO    Kane Regional Centers
# 1          JOY M      ABBOTT    Kane Regional Centers
# 2        KEVIN J      ABBOTT     Emergency Management
# 3        JASMINE       ABRAM            Shuman Center
# 4    GWENDOLYN S  ABRAMOVITZ  Administrative Services
# 5      ANTHONY A       ACHES                   Police
# 6        KIARA N  ACIE-SCOTT    Kane Regional Centers
# 7       JEREMY G       ACKER    Kane Regional Centers
# 8        MASON N    ACKERMAN                    Parks
# 9      MICHAEL E     ACQUARO                    Parks
# 10     SUZANNE J       ACRIE           Human Services
# 11      CONNOR J       ADAIR        District Attorney
# 12        MARY E    ADAMCZYK         County Solicitor
# 13     ABIGAIL H       ADAMS                     Jail
# 14        JOHN V   ADAMS III                    Parks
# 15     MICHAEL P     ADAMSKI    Kane Regional Centers
# ...
